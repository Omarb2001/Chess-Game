# %% [markdown]
# # UTSA CS 3793: Assignment-2
#
# **Last Name - First Name - (abc123)**

# %% [markdown]
# ## Learning Objectives
#
#
#
# *   Game Playing
# *   Chess - Board Setup & Rules
# *   Adversarial Search
# *   AI - Random vs MinMax

# %% [markdown]
# ## Description
#
# This assignment is focused on **game playing** and creating a proper **AI for chess**.
# In the following sections, you will complete a series of tasks to create a chess game board, rules for each chess piece, a Random AI and a MinMax AI that plays a game of chess for both players (white and black).
#
# The base structure of the code is provided. You are supposed to write code for each of the functions. Comments are provided on what should be done. You **CANNOT** use a complete chess library and change the base code structure completely. However, you **CAN** change the code layout and name/format of the functions.

# %% [markdown]
# #Chess Board Setup & Rules
#
# In this section, you will write code to import the necessary libraries and create:
#
# 1.   **ChessBoard** - This part will contain code to initialize the board, draw the board, get the board state and move piece.
# 2.   **ChessRules** - This part will contain code for the chess rules for each piece.

# %% [markdown]
# ##Import Libraries
#
# The code here will contain only **import** statements. A base list of the required libraries are already imported. You will most likely not need any other libraries, but if needed, add the import statements here. As mentioned before, you can not use any premade chess libraries.

# %%
# your code goes here
import string
import random
import os
import sys
import time
import copy
from IPython.display import clear_output

# %% [markdown]
# ##ChessBoard
#
# (10 points)
#
# Fill the code in the code structure provided below for the ChessBoard. The main use of this code block write functions to initialize the board, draw the board, get the board state and move piece. You can add any other functions if needed.

# %%
def ChessBoardSetup():
    boardArray = [
        ['r','t','b','q','k','b','t','r'],
        ['p','p','p','p','p','p','p','p'],
        ['.','.','.','.','.','.','.','.'],
        ['.','.','.','.','.','.','.','.'],
        ['.','.','.','.','.','.','.','.'],
        ['.','.','.','.','.','.','.','.'],
        ['P','P','P','P','P','P','P','P'],
        ['R','T','B','K','Q','B','T','R']
     ]
    return boardArray


def DrawBoard(boardA):
    #clear_output(wait = True)
    for row in range(0,len(board[0])):
        for column in range(0,len(board[1])):
            print(" " + boardA[row][column] + " ", end="")
        print()


def MovePiece(board, currentPos, destinationPos):
    board[destinationPos[0]][destinationPos[1]] = board[currentPos[0]][currentPos[1]]
    board[currentPos[0]][currentPos[1]] = '.'
    return board

# %% [markdown]
# ##ChessRules
#
# (50 points)
#
# Fill the code in the code structure provided below for ChessRules. The main use of the code block is to write functions to design the rules for movement of each piece on the board. This block will also contain the function to check if the current player is in check, check-mate. You can also have functions that can return the current player's pieces that have legal moves in the current board state.
#
# Following are some **suggested** functions with the pseudocode provided. You can create/remove functions as needed.

# %%
def IsMoveLegal(board,InitialPos, FinalPos, round):
# input is from-square and to-square
# use the input and the board to get the from-piece and to-piece

# if from-square is the same as to-square
# return False
    if InitialPos[0] == FinalPos[0] and InitialPos[1] == FinalPos[1]:
        return False
# if any position is out of the bounds of the chess boards

    elif InitialPos[0] < 0 or FinalPos[0] < 0 or InitialPos[0] > 7 or FinalPos[0] > 7 or InitialPos[1] < 0 or FinalPos[1] < 0 or InitialPos[1] > 7 or FinalPos[1] > 7:
        return False

    piece = board[InitialPos[0]][InitialPos[1]]
    destSquare = board[FinalPos[0]][FinalPos[1]]
# check if there even is a piece

    if piece == '.':
        return False

    blackPieces = ['p', 'r', 't', 'b', 'q', 'k']
    whitePieces = ['P', 'R', 'T', 'B', 'Q', 'K']

# Check what the current round is. We don't want the player the move the enemy's pieces

    if round.lower() == 'white':
        # We're checking if we're even allowed to move this piece
        if piece not in whitePieces:
            return False
        if piece == "P":
            if FinalPos == [InitialPos[0]-1, InitialPos[1]] and destSquare == '.':
                return True
            elif FinalPos[1] == InitialPos[1] and InitialPos[0] == 6 and FinalPos[0] == 4 and destSquare == '.':
                if IsClearPath(board, InitialPos, FinalPos):
                    return True
            elif (FinalPos == [InitialPos[0]-1, InitialPos[1]-1] or FinalPos == [InitialPos[0]-1, InitialPos[1]+1]) and destSquare in blackPieces:
                return True
        elif piece == 'R':
            if FinalPos[0] == InitialPos[0] or FinalPos[1] == InitialPos[1] and (not FinalPos[0] == InitialPos[0] and FinalPos[1] == InitialPos[1]):
                if destSquare == '.' or destSquare in blackPieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
        elif piece == 'B':
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if x == y:
                if destSquare == '.' or destSquare in blackPieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
        elif piece == 'T':
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if destSquare == '.' or destSquare in blackPieces:
                if x == 1 and y == -2:
                    return True
                elif x == 2 and y == -1:
                    return True
                elif x == 2 and y == 1:
                    return True
                elif x == 1 and y == 2:
                    return True
                elif x == -1 and y == -2:
                    return True
                elif x == -2 and y == -1:
                    return True
                elif x == -2 and y == 1:
                    return True
                elif x == -1 and y == 2:
                    return True
        elif piece == 'Q':
            if (FinalPos[0] == InitialPos[0] or FinalPos[1] == InitialPos[1]) and (not (FinalPos[0] == InitialPos[0] and FinalPos[1] == InitialPos[1])):
                if destSquare == '.' or destSquare in blackPieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if x == y:
                if destSquare == '.' or destSquare in blackPieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
        elif piece == 'K':
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if destSquare == '.' or destSquare in blackPieces:
                if abs(x) == 1 and abs(y) == 0:
                    return True
                elif abs(x) == 0 and abs(y) == 1:
                    return True
                elif abs(x) == 1 and abs(y) == 1:
                    return True

    elif round.lower() == 'black':
        # We're checking if we're even allowed to move this piece
        if piece not in blackPieces:
            return False
        if piece == 'p':
            if FinalPos == [InitialPos[0]+1, InitialPos[1]] and destSquare == '.':
                return True
            elif FinalPos[1] == InitialPos[1] and InitialPos[0] == 1 and FinalPos[0] == 3 and destSquare == '.':
                if IsClearPath(board, InitialPos, FinalPos):
                    return True
            elif (FinalPos == [InitialPos[0]+1, InitialPos[1]+1] or FinalPos == [InitialPos[0]+1, InitialPos[1]-1]) and destSquare in whitePieces:
                return True
        elif piece == 'r':
            if (FinalPos[0] == InitialPos[0] or FinalPos[1] == InitialPos[1]) and (not (FinalPos[0] == InitialPos[0] and FinalPos[1] == InitialPos[1])):
                if destSquare == '.' or destSquare in whitePieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
        elif piece == 'b':
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if abs(x) == abs(y):
                if destSquare == '.' or destSquare in whitePieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
        elif piece == 't':
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if destSquare == '.' or destSquare in whitePieces:
                if x == 1 and y == -2:
                    return True
                elif x == 2 and y == -1:
                    return True
                elif x == 2 and y == 1:
                    return True
                elif x == 1 and y == 2:
                    return True
                elif x == -1 and y == -2:
                    return True
                elif x == -2 and y == -1:
                    return True
                elif x == -2 and y == 1:
                    return True
                elif x == -1 and y == 2:
                    return True
        elif piece == 'q':
            if (FinalPos[0] == InitialPos[0] or FinalPos[1] == InitialPos[1]) and (not (FinalPos[0] == InitialPos[0] and FinalPos[1] == InitialPos[1])):
                if destSquare == '.' or destSquare in whitePieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if abs(x) == abs(y):
                if destSquare == '.' or destSquare in whitePieces:
                    if IsClearPath(board, InitialPos, FinalPos):
                        return True
        elif piece == 'k':
            y = FinalPos[0] - InitialPos[0]
            x = FinalPos[1] - InitialPos[1]
            if destSquare == '.' or destSquare in whitePieces:
                if abs(x) == 1 and abs(y) == 0:
                    return True
                elif abs(x) == 0 and abs(y) == 1:
                    return True
                elif abs(x) == 1 and abs(y) == 1:
                    return True

    return False


def GetListOfLegalMoves(board, position, round):
    legalMoves = list()
    for row in range(0,len(board[0])):
        for column in range(0,len(board[1])):
            if IsMoveLegal(board, position, [row, column], round):
                if not DoesMovePutPlayerInCheck(board, position, [row, column], round):
                    legalMoves.append([row, column])

    return legalMoves


def GetPiecesWithLegalMoves(board, round):
    moves = list()
    pieces = list()
    blackPieces = ['p', 'r', 't', 'b', 'q', 'k']
    whitePieces = ['P', 'R', 'T', 'B', 'Q', 'K']
    for row in range(0,len(board[0])):
        for column in range(0,len(board[1])):
            if round.lower() == 'white':
                if board[row][column] in whitePieces:
                    moves = GetListOfLegalMoves(board, [row,column], round)
                    if moves:
                        pieces.append([row,column])
            elif round.lower() == 'black':
                if board[row][column] in blackPieces:
                    moves = GetListOfLegalMoves(board, [row,column], round)
                    if moves:
                        pieces.append([row,column])
    return pieces


# returns True if the current player is in checkmate, else False
def IsCheckmate(board, round):
    pieces = list()
    pieces = GetPiecesWithLegalMoves(board,round)
    if not pieces:
        return True
    return False

# returns True if the given player is in Check state
def IsInCheck(board, round):
    king = list()
    if round.lower() == 'white':
        for row in range(0, len(board[0])):
            for column in range(0, len(board[1])):
                if board[row][column] == 'K':
                    king = [row, column]
    elif round.lower() == 'black':
        for row in range(0, len(board[0])):
            for column in range(0, len(board[1])):
                if board[row][column] == 'k':
                    king = [row, column]
    if not king:
        return True
    blackPieces = ['p', 'r', 't', 'b', 'q', 'k']
    whitePieces = ['P', 'R', 'T', 'B', 'Q', 'K']

    for row in range(0, len(board[0])):
        for column in range(0, len(board[1])):
            if round.lower() == 'white':
                if board[row][column] in blackPieces:
                    return IsMoveLegal(board, [row, column], king, 'black')
            if round.lower() == 'black':
                if board[row][column] in whitePieces:
                    return IsMoveLegal(board, [row, column], king, 'white')
    return False

# helper function to figure out if a move is legal for straight-line moves (rooks, bishops, queens, pawns)
# returns True if the path is clear for a move (from-square and to-square), non-inclusive
def IsClearPath(board, InitialPos, FinalPos):
    if abs(FinalPos[0] - InitialPos[0]) <= 1 and abs(FinalPos[1] - InitialPos[1]) <= 1:
        return True
    new_from_square = list()
    if InitialPos[1] == FinalPos[1] and FinalPos[0] - InitialPos[0] >= 1:
        new_from_square = [InitialPos[0]+1,InitialPos[1]]
    elif InitialPos[1] == FinalPos[1] and FinalPos[0] - InitialPos[0] <=-1:
        new_from_square = [InitialPos[0]-1,InitialPos[1]]
    elif InitialPos[0] == FinalPos[0] and FinalPos[1] - InitialPos[1] >= 1:
        new_from_square = [InitialPos[0],InitialPos[1]+1]
    elif InitialPos[0] == FinalPos[0] and FinalPos[1] - InitialPos[1] <=-1:
        new_from_square = [InitialPos[0],InitialPos[1]-1]
    elif abs(FinalPos[0] - InitialPos[0]) == abs(FinalPos[1] - InitialPos[1]):
        if FinalPos[0] - InitialPos[0] >=1 and FinalPos[1] - InitialPos[1] >=1:
            new_from_square = [InitialPos[0]+1,InitialPos[1]+1]
        elif FinalPos[0] - InitialPos[0] >= 1 and FinalPos[1] - InitialPos[1] <= -1:
            new_from_square = [InitialPos[0]+1,InitialPos[1]-1]
        elif FinalPos[0] - InitialPos[0] <= -1 and FinalPos[1] - InitialPos[1] >= 1:
            new_from_square = [InitialPos[0]-1,InitialPos[1]+1]
        elif FinalPos[0] - InitialPos[0] <= -1 and FinalPos[1] - InitialPos[1] <= -1:
            new_from_square = [InitialPos[0] - 1, InitialPos[1] -1]
    else:
        return False

    if board[new_from_square[0]][new_from_square[1]] != '.':
        return False
    else:
        return IsClearPath(board, new_from_square, FinalPos)

# makes a hypothetical move (from-square and to-square)
# returns True if it puts current player into check
def DoesMovePutPlayerInCheck(board, InitialPos, FinalPos, round):
# given the move (from-square and to-square), find the 'from-piece' and 'to-piece'
# make the move temporarily by changing the 'board'
    tempBoard = copy.deepcopy(board)
    if IsMoveLegal(tempBoard, InitialPos, FinalPos, round):
        MovePiece(tempBoard, InitialPos, FinalPos)
    return IsInCheck(tempBoard, round)

# %% [markdown]
# #Artificial Intelligence
#
# In this section, you will write code for the Artificial Intelligence (AI) that will play a game of chess. You will write 2 types of AI:
#
# 1.   **RandomAI** - This part will contain code for moving a chess piece randomly.
# 2.   **MinMaxAI** - This part will contain code for moving a chess piece using the MinMax strategy discussed in the lecture.

# %% [markdown]
# ##RandomAI
#
# (10 points)
#
# Complete the function below that will perform a random move for the given player. The function will return the move (from-piece and to-piece). You will most likely not need to write any other function, but you can, if needed.

# %%
def GetRandomMove(board, round):
    pieces = GetPiecesWithLegalMoves(board, round)
    piece = random.choice(pieces)
    moves = GetListOfLegalMoves(board, piece, round)
    move = random.choice(moves)

    return piece , move

# %% [markdown]
# ##MinMaxAI
#
# (50 points)
#
# Complete the functions below that will perform a move for the given player using the MinMax AI strategy. One function will evaluate the board if a move is performed - give score for each of piece and calculate the score for the entire chess board. In the second function you will write actual code for the MinMax strategy and return the move (from-piece and to-piece). To get the allocated points, searching should be **2-ply (one Max and one Min)**. You will most likely not need to write any other function, but you can, if needed.
#
# ## Extra Credit
#
# *   **(5 points)** Modify the above MinMax strategy to be **4-ply (one Max, one Min, one Max, one Min)**.
# *   **(10 points)** Perform **alpha-beta pruning** for the MinMax strategy.

# %%
def evl(board, round):
    score = 0
    if round.lower() == 'white':
        for row in range(0, len(board[0])):
            for column in range(0, len(board[1])):
                if board[row][column] == 'p':
                    score = score - 10
                elif board[row][column] == 'P':
                    score = score + 10
                elif board[row][column] == 't' or board[row][column] == 'b':
                    score = score - 30
                elif board[row][column] == 'T' or board[row][column] == 'B':
                    score = score + 30
                elif board[row][column] == 'r':
                    score = score - 50
                elif board[row][column] == 'R':
                    score = score + 50
                elif board[row][column] == 'q':
                    score = score - 90
                elif board[row][column] == 'Q':
                    score = score + 90
                elif board[row][column] == 'k':
                    score = score - 900
                elif board[row][column] == 'K':
                    score = score + 900
    else:
        for row in range(0, len(board[0])):
            for column in range(0, len(board[1])):
                if board[row][column] == 'p':
                    score = score + 10
                elif board[row][column] == 'P':
                    score = score - 10
                elif board[row][column] == 't' or board[row][column] == 'b':
                    score = score + 30
                elif board[row][column] == 'T' or board[row][column] == 'B':
                    score = score - 30
                elif board[row][column] == 'r':
                    score = score + 50
                elif board[row][column] == 'R':
                    score = score - 50
                elif board[row][column] == 'q':
                    score = score + 90
                elif board[row][column] == 'Q':
                    score = score - 90
                elif board[row][column] == 'k':
                    score = score + 900
                elif board[row][column] == 'K':
                    score = score - 900
    return score




def GetMinMaxMove(board, round):
    pieces = GetPiecesWithLegalMoves(board, round)
    bestenemyeval = 100000
    besteval = -100000
    bestEnemyMove = list()
    bestMove = list()
    for piece in pieces:
        moves = GetListOfLegalMoves(board, piece, round)
        for move in moves:
            tempBoard = copy.deepcopy(board)
            MovePiece(tempBoard, piece, move)
            enemyPieces = list()
            if round.lower() == 'white':
                enemyPieces = GetPiecesWithLegalMoves(board, 'black')
            else:
                enemyPieces = GetPiecesWithLegalMoves(board, 'white')
            for enemyPiece in enemyPieces:
                enemyMoves = list()
                if round.lower() == 'white':
                    enemyMoves = GetListOfLegalMoves(board, enemyPiece,'black')
                else:
                    enemyMoves = GetListOfLegalMoves(board, enemyPiece,'white')
                for enemyMove in enemyMoves:
                    tempBoardEnemy = copy.deepcopy(tempBoard)
                    MovePiece(tempBoardEnemy,enemyPiece, enemyMove)
                    res = evl(tempBoardEnemy, round)
                    if res <= bestenemyeval:
                        bestenemyeval = res
                        bestEnemyMove = [enemyPiece,enemyMove]
            if bestenemyeval >= besteval:
                besteval = bestenemyeval
                bestMove = [piece, move]
    if bestMove:
        return bestMove[0], bestMove[1]
    else:
        return GetRandomMove(board,round)

# %% [markdown]
# #Game Setup & Main Loop
#
# (05 points)
#
# Write code below to have a game-play between two AIs - Random vs MinMax. For each iteration, draw the board before and after a turn.

# %%
board = ChessBoardSetup()

round = str()
while (round.lower() !='white' and round.lower() !='black'):
    clear_output()
    round = input("Who would you like to start first:\n(white(uppercase pieces)/black(lowercase pieces): ")

print("begin!")
time.sleep(3)
N = 10000
turns = 1
while not IsCheckmate(board, round) and turns < N:
    clear_output()
    DrawBoard(board)


    if turns%2==1:
        if IsCheckmate(board, round):
            break
        From, To = GetMinMaxMove(board, round)
        MovePiece(board, From, To)
        if round.lower() == 'white':
            round = 'black'
        else:
            round = 'white'
    else:
        if IsCheckmate(board, round):
            break
        From, To = GetRandomMove(board, round)
        MovePiece(board, From, To)
        if round.lower() == 'white':
            round = 'black'
        else:
            round = 'white'
    turns = turns + 1
    time.sleep(0.5)
    print("\n\n\n")


if not IsCheckmate(board, round):
    print("It's a stalemate!")
else:
    if round.lower() == 'black':
        print("White won!")
    else:
        print("Black won!")

sys.exit(0)

# %% [markdown]
# #Submission Instructions
#
# 1.   Complete all tasks above - **File MUST contain the output for ALL cells**
# 2.   Export this notebook as .ipynb
#       (File > Download as ipynb)
# 3.   Upload the .ipynb file on Blackboard

# %% [markdown]
# ##Rubric
#
# *   (10 points) Chess Board Setup
# *   (50 points) Chess Rules Setup
# *   (10 points) Random AI
# *   (50 points) MinMax AI (2-ply)
# *   (05 points) Game Main Loop - Random vs MinMax
# *   (15 points) Extra Credit - 4-ply MinMax + alpha-beta pruning
